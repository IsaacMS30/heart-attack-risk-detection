# %% [markdown]
# # Heart Attack Risk Detection - Data Preprocessing
#
# In this notebook, you will find some actions made on the data. The goal is preparing the data to train machine learning models.

# %%
import sys
sys.path.append("../src")

import data.make_dataset as data
import data.preprocessing as prep

import importlib
importlib.reload(data)
importlib.reload(prep)
# Out:
# <module 'data.preprocessing' from 'c:\\Users\\isaac\\Documents\\GitHub\\heart-attack-risk-detection\\notebooks\\../src\\data\\preprocessing.py'>

# %%
# Load data
df = data.load_dataset("../data/raw/dataset.csv")
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# 2      1                 0       0
# 3      2                 2       1
# 4      3                 2       1

# %% [markdown]
# ## Cleaning data
#
# First, we will drop some columns that are not necessary (patient ID).

# %%
# Drop unnecessary columns
df = prep.drop_columns(df, ["patientid"])
df
# Out:
#      age  gender  chestpain  restingBP  serumcholestrol  fastingbloodsugar  \
# 0     53       1          2        171                0                  0
# 1     40       1          0         94              229                  0
# 2     49       1          2        133              142                  0
# 3     43       1          0        138              295                  1
# 4     31       1          1        199                0                  0
# ..   ...     ...        ...        ...              ...                ...
# 995   48       1          2        139              349                  0
# 996   47       1          3        143              258                  1
# 997   69       1          0        156              434                  1
# 998   45       1          1        186              417                  0
# 999   25       1          0        158              270                  0
#
#      restingrelectro  maxheartrate  exerciseangia  oldpeak  slope  \
# 0                  1           147              0      5.3      3
# 1                  1           115              0      3.7      1
# 2                  0           202              1      5.0      1
# 3                  1           153              0      3.2      2
# 4                  2           136              0      5.3      3
# ..               ...           ...            ...      ...    ...
# 995                2           183              1      5.6      2
# 996                1            98              1      5.7      1
# 997                0           196              0      1.4      3
# 998                1           117              1      5.9      3
# 999                0           143              1      4.7      0
#
#      noofmajorvessels  target
# 0                   3       1
# 1                   1       0
# 2                   0       0
# 3                   2       1
# 4                   2       1
# ..                ...     ...
# 995                 2       1
# 996                 0       0
# 997                 1       1
# 998                 2       1
# 999                 0       0
#
# [1000 rows x 13 columns]

# %% [markdown]
# ## Feature engineering
#
# Since there are no missing values nor non-numerical values, we can directly store our dataset after being processed.

# %%
df.dtypes
# Out:
# age                    int64
# gender                 int64
# chestpain              int64
# restingBP              int64
# serumcholestrol        int64
# fastingbloodsugar      int64
# restingrelectro        int64
# maxheartrate           int64
# exerciseangia          int64
# oldpeak              float64
# slope                  int64
# noofmajorvessels       int64
# target                 int64
# dtype: object

# %% [markdown]
# Now, dataset is ready to train models. Let's save it.

# %%
prep.save_dataset(df, "dataset-processed.csv")
